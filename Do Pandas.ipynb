# %%
import pandas as pd
import numpy as np

# %%
dat=pd.read_csv("covid_19_india.csv")
dat.info
# Out:
# <bound method DataFrame.info of        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 6171  6172  11/09/20  8:00 AM            Telengana                       -
# 6172  6173  11/09/20  8:00 AM              Tripura                       -
# 6173  6174  11/09/20  8:00 AM          Uttarakhand                       -
# 6174  6175  11/09/20  8:00 AM        Uttar Pradesh                       -
# 6175  6176  11/09/20  8:00 AM          West Bengal                       -
#
# ...

# %%
dat1=dat[dat["Date"]=="11/09/20"]
dat1=dat1.sort_values(by="Confirmed",ascending=False)
dat1
# Out:
#        Sno      Date     Time                      State/UnionTerritory  \
# 6160  6161  11/09/20  8:00 AM                               Maharashtra
# 6142  6143  11/09/20  8:00 AM                            Andhra Pradesh
# 6170  6171  11/09/20  8:00 AM                                Tamil Nadu
# 6156  6157  11/09/20  8:00 AM                                 Karnataka
# 6174  6175  11/09/20  8:00 AM                             Uttar Pradesh
# 6149  6150  11/09/20  8:00 AM                                     Delhi
# 6175  6176  11/09/20  8:00 AM                               West Bengal
# 6145  6146  11/09/20  8:00 AM                                     Bihar
# 6171  6172  11/09/20  8:00 AM                                 Telengana
# 6165  6166  11/09/20  8:00 AM                                    Odisha
# 6144  6145  11/09/20  8:00 AM                                     Assam
# 6151  6152  11/09/20  8:00 AM                                   Gujarat
# ...

# %%
df1=dat[dat['State/UnionTerritory']=='Maharashtra']
df1.head()
# Out:
#      Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 76    77  09/03/20  6:00 PM          Maharashtra                       2
# 91    92  10/03/20  6:00 PM          Maharashtra                       5
# 97    98  11/03/20  6:00 PM          Maharashtra                       2
# 120  121  12/03/20  6:00 PM          Maharashtra                      11
# 133  134  13/03/20  6:00 PM          Maharashtra                      14
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# 76                         0      0       0          2
# 91                         0      0       0          5
# 97                         0      0       0          2
# 120                        0      0       0         11
# 133                        0      0       0         14

# %%
df2=dat[dat['State/UnionTerritory']=='Tamil Nadu']
df2.head()
# Out:
#      Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 61    62  07/03/20  6:00 PM           Tamil Nadu                       1
# 67    68  08/03/20  6:00 PM           Tamil Nadu                       1
# 79    80  09/03/20  6:00 PM           Tamil Nadu                       1
# 94    95  10/03/20  6:00 PM           Tamil Nadu                       1
# 105  106  11/03/20  6:00 PM           Tamil Nadu                       1
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# 61                         0      0       0          1
# 67                         0      0       0          1
# 79                         0      0       0          1
# 94                         0      0       0          1
# 105                        0      0       0          1

# %%
df3=pd.concat([df1,df2],axis=0,sort=False)
df3.head()
# Out:
#      Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 76    77  09/03/20  6:00 PM          Maharashtra                       2
# 91    92  10/03/20  6:00 PM          Maharashtra                       5
# 97    98  11/03/20  6:00 PM          Maharashtra                       2
# 120  121  12/03/20  6:00 PM          Maharashtra                      11
# 133  134  13/03/20  6:00 PM          Maharashtra                      14
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# 76                         0      0       0          2
# 91                         0      0       0          5
# 97                         0      0       0          2
# 120                        0      0       0         11
# 133                        0      0       0         14

# %%
df3.tail()
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 6030  6031  07/09/20  8:00 AM           Tamil Nadu                       -
# 6065  6066  08/09/20  8:00 AM           Tamil Nadu                       -
# 6100  6101  09/09/20  8:00 AM           Tamil Nadu                       -
# 6135  6136  10/09/20  8:00 AM           Tamil Nadu                       -
# 6170  6171  11/09/20  8:00 AM           Tamil Nadu                       -
#
#      ConfirmedForeignNational   Cured  Deaths  Confirmed
# 6030                        -  404186    7836     463480
# 6065                        -  410116    7925     469256
# 6100                        -  416715    8012     474940
# 6135                        -  423231    8090     480524
# 6170                        -  429416    8154     486052

# %%
df4=dat[dat['State/UnionTerritory']==  'Andhra Pradesh']
df4.head()
# Out:
#      Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 121  122  12/03/20  6:00 PM       Andhra Pradesh                       1
# 134  135  13/03/20  6:00 PM       Andhra Pradesh                       1
# 147  148  14/03/20  6:00 PM       Andhra Pradesh                       1
# 148  149  15/03/20  6:00 PM       Andhra Pradesh                       1
# 162  163  16/03/20  6:00 PM       Andhra Pradesh                       1
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# 121                        0      0       0          1
# 134                        0      0       0          1
# 147                        0      0       0          1
# 148                        0      0       0          1
# 162                        0      0       0          1

# %%
df3=pd.concat([df3,df4],axis=0,sort=False)
df3.head()
# Out:
#      Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 76    77  09/03/20  6:00 PM          Maharashtra                       2
# 91    92  10/03/20  6:00 PM          Maharashtra                       5
# 97    98  11/03/20  6:00 PM          Maharashtra                       2
# 120  121  12/03/20  6:00 PM          Maharashtra                      11
# 133  134  13/03/20  6:00 PM          Maharashtra                      14
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# 76                         0      0       0          2
# 91                         0      0       0          5
# 97                         0      0       0          2
# 120                        0      0       0         11
# 133                        0      0       0         14

# %%
df3.tail()
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 6002  6003  07/09/20  8:00 AM       Andhra Pradesh                       -
# 6037  6038  08/09/20  8:00 AM       Andhra Pradesh                       -
# 6072  6073  09/09/20  8:00 AM       Andhra Pradesh                       -
# 6107  6108  10/09/20  8:00 AM       Andhra Pradesh                       -
# 6142  6143  11/09/20  8:00 AM       Andhra Pradesh                       -
#
#      ConfirmedForeignNational   Cured  Deaths  Confirmed
# 6002                        -  394019    4417     498125
# 6037                        -  404074    4487     506493
# 6072                        -  415765    4560     517094
# 6107                        -  425607    4634     527512
# 6142                        -  435647    4702     537687

# %%
ab=pd.DataFrame([[29.9,"good",12],[12,"bad",20],[21,22,23]],columns=["marks","view","score"])
ab
# Out:
#    marks  view  score
# 0   29.9  good     12
# 1   12.0   bad     20
# 2   21.0    22     23

# %%
l1=[20,29,"mark"]
a=np.array(l1)
print(a)
# Out:
# ['20' '29' 'mark']

# %%
type(a)
# Out:
# numpy.ndarray

# %%
z=12
print(z)
# Out:
# 12

# %%
type(z)
# Out:
# int

# %%
type(ab)
# Out:
# pandas.core.frame.DataFrame
